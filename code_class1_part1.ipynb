# %% [markdown]
# #Generacion de inputs (x)
#   ```
#   x=seq(1,5,by=0.05)
#   n=length(x) #numero de datos
# ```
#   [More info.](https://pynative.com/python-range-for-float-numbers/)

# %%
import numpy as np
x= np.arange(1,5,0.05)
n= len(x)

# %% [markdown]
# #Funcion de media de Y dado X
#   `mean=rep(2,n)+.3*x+x^.4*2+cos(x*4)*.5`
#
#   `plot(x,mean,type="l",col=2,lwd=2)`

# %%
mean = 2+0.3*x+2*x**0.4+0.5*np.cos(x*4)

# %%
import matplotlib.pyplot as plt
plt.figure(1,figsize=(8,8))
plt.plot(x,mean,linewidth=2,color='magenta')
plt.title('Mean vs x',fontsize=20)
plt.xlabel('x',fontsize=15)
plt.ylabel('y',fontsize=15)
plt.show()

# %% [markdown]
# #Generacion de datos (X,Y)
#
# ```
#  y=mean+rnorm(n,0,.5)
#  plot(x,y)
#  points(x,mean,type="l",col=2,lwd=2)  #adicion de media
# ```
#
# [Numpy random normal.](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.random.normal.html)

# %%
mu, sigma = 0, 0.5 # mean and standard deviation
s = np.random.normal(mu, sigma, n) #n is the number or required elements
y = mean + s

plt.figure(1,figsize=(8,8))
plt.plot(x,mean,linewidth=2,color='magenta')
plt.title('Mean vs x',fontsize=20)
plt.xlabel('x',fontsize=15)
plt.ylabel('y',fontsize=15)
plt.scatter(x,y, color='blue')
plt.show()

# %% [markdown]
# #Generacion de nuevas muestras (1 y 2)
# ```
#   x1=runif(10,1,5)
#   x2=runif(10,1,5)
#   n2=10   #tamano de nuevas muestras
#   mean1=rep(2,n2)+.3*x1+x1^.4*2+cos(x1*4)*.5
#   mean2=rep(2,n2)+.3*x2+x2^.4*2+cos(x2*4)*.5
# ```
#
# [Numpy random uniform.](https://docs.scipy.org/doc/numpy-1.15.0/reference/generated/numpy.random.uniform.html)
#
# numpy.random.uniform(low,high,size)
#
# Parameters:
# low : float or array_like of floats, optional
# Lower boundary of the output interval. All values generated will be greater than or equal to low. The default value is 0.
#
# high : float or array_like of floats
# Upper boundary of the output interval. All values generated will be less than high. The default value is 1.0.
#
# size : int or tuple of ints, optional
# Output shape. If the given shape is, e.g., (m, n, k), then m * n * k samples are drawn. If size is None (default), a single value is returned if low and high are both scalars. Otherwise, np.broadcast(low, high).size samples are drawn.

# %%
x1  = np.random.uniform(1,5,10)
x2  = np.random.uniform(1,5,10)
n2  = 10
mean1 =  2+0.3*x1+2*x1**0.4+0.5*np.cos(x1*4)
mean2 =  2+0.3*x2+2*x2**0.4+0.5*np.cos(x2*4)

# %% [markdown]
# #Gráfico de muestra 1
#  ```
#   y1=mean1+rnorm(n2,0,.5)
#   plot(x1,y1,xlim=c(1,5),ylim=c(3.8,8.5),main="Muestra 1",xlab="x",ylab="y")
#   points(x,mean,type="l",col=2,lwd=2)
#   ```

# %%
plt.figure(1,figsize=(8,8))
y1 = mean1 + np.random.normal(0,0.5,n2)
plt.scatter(x1,y1,color='green')
plt.title('Muestra 1')
plt.xlabel('x')
plt.ylabel('y')
plt.plot(x,mean, color='magenta')
plt.show()

# %% [markdown]
# #Gráfico de muestra 2
# ```
#   y2=mean2+rnorm(n2,0,.5)
#   plot(x2,y2,xlim=c(1,5),ylim=c(3.8,8.5),main="Muestra 2",xlab="x",ylab="y")
#   points(x,mean,type="l",col=2,lwd=2)
# ```

# %%
plt.figure(1,figsize=(8,8))
y2 = mean2 + np.random.normal(0,0.5,n2)
plt.scatter(x2,y2,color='red')
plt.title('Muestra 2')
plt.xlabel('x')
plt.ylabel('y')
plt.plot(x,mean, color='magenta')
plt.show()

# %% [markdown]
# # ¿Cómo se vería en un subplot?

# %%
plt.figure(1,figsize=(16,5))

#code for fig 1
plt.subplot(121)
plt.scatter(x1,y1,color='green')
plt.title('Muestra 1')
plt.xlabel('x')
plt.ylabel('y')
plt.plot(x,mean, color='magenta')

#code for fig 2
plt.subplot(122)
plt.scatter(x2,y2,color='red')
plt.title('Muestra 2')
plt.xlabel('x')
plt.ylabel('y')
plt.plot(x,mean, color='magenta')

plt.show() #este show se incluye al final
